# %%
# Ques 1. Given a linked list of N nodes. The task is to reverse this list.

# Example 1:

# Input:

# LinkedList: 1->2->3->4->5->6

# Output: 6 5 4 3 2 1

# Explanation: After reversing the list,

# Elements are 6->5->4->3->2->1.

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
 
 
class LinkedList:
 
    def __init__(self):
        self.head = None
 
    def reverse(self):
        prev = None
        current = self.head
        while(current is not None):
            next = current.next
            current.next = prev
            prev = current
            current = next
        self.head = prev
 
    def push(self, new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
 
    def printList(self):
        temp = self.head
        while(temp):
            print(temp.data, end="->")
            temp = temp.next
 
 
linkedList = LinkedList()
linkedList.push(6)
linkedList.push(5)
linkedList.push(4)
linkedList.push(3)
linkedList.push(2)
linkedList.push(1)
 
print("Linked List")
linkedList.printList()
linkedList.reverse()
print("\nReversed Linked List")
linkedList.printList()
# Out:
# Linked List
# 1->2->3->4->5->6->
# Reversed Linked List
# 6->5->4->3->2->1->

# %%
# Ques 2. Given two sorted linked lists consisting of N and M nodes respectively. The task is to merge both of the list (in-place) and return head of the merged list.

# Example 1:

# Input:

# N = 4, M = 3

# ValueN[] = {5,10,15,40}

# ValueM[] = {2,3,20}

# Output: 2 3 5 10 15 20 40

# Explanation: After merging the two linked

# Lists, we have merged list as 2, 3, 5,

# 10, 15, 20, 40.

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
 
 
class LinkedList:
    def __init__(self):
        self.head = None
 
    def printList(self):
        temp = self.head
        while temp:
            print(temp.data, end=" ")
            temp = temp.next
 
    def addToList(self, newData):
        newNode = Node(newData)
        if self.head is None:
            self.head = newNode
            return
 
        last = self.head
        while last.next:
            last = last.next
 
        last.next = newNode
 
 
def mergeLists(headA, headB):
 
    dummyNode = Node(0)
 
    tail = dummyNode
    while True:

        if headA is None:
            tail.next = headB
            break
        if headB is None:
            tail.next = headA
            break
 
        if headA.data <= headB.data:
            tail.next = headA
            headA = headA.next
        else:
            tail.next = headB
            headB = headB.next
 
        tail = tail.next
 
    return dummyNode.next
 
 

listA = LinkedList()
listB = LinkedList()
 
listA.addToList(5)
listA.addToList(10)
listA.addToList(15)
 
listB.addToList(2)
listB.addToList(3)
listB.addToList(20)
 
listA.head = mergeLists(listA.head, listB.head)
 
print("Merged Linked List is:")
listA.printList()
# Out:
# Merged Linked List is:
# 2 3 5 10 15 20

# %%
# Ques 3. Given a doubly linked list and a position. The task is to delete a node from given position in a doubly linked list.

# Example 1:

# Input:

# LinkedList = 1 <--> 3 <--> 4

# X = 3

# Output: 1 3 

# Explanation: After deleting the node at

# Position 3 (position starts from 1),

# The linked list will be now as 1->3.

class Node:
     
    # Constructor to create a new node
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
def deleteNode(head_ref, del_):
 
    if (head_ref == None or del_ == None):
        return
 
    if (head_ref == del_):
        head_ref = del_.next
 
    if (del_.next != None):
        del_.next.prev = del_.prev
 
    if (del_.prev != None):
        del_.prev.next = del_.next
         
    return head_ref
 
 
def deleteNodeAtGivenPos(head_ref,n):
 
    # if list in None or invalid position is given
    if (head_ref == None or n <= 0):
        return
 
    current = head_ref
    i = 1
 
    while ( current != None and i < n ):
        current = current.next
        i = i + 1
 
    if (current == None):
        return
 
    deleteNode(head_ref, current)
     
    return head_ref
 
def push(head_ref, new_data):
 
    new_node = Node(0)
 
    new_node.data = new_data
 
    new_node.prev = None
 
    new_node.next = (head_ref)
 
    if ((head_ref) != None):
        (head_ref).prev = new_node
 
    (head_ref) = new_node
     
    return head_ref
 
def printList(head):
 
    while (head != None) :
        print( head.data ,end= "<-->")
        head = head.next
     
 
head = None
 
head = push(head, 4)
head = push(head, 3)
head = push(head, 1)
 
print("Doubly linked list before deletion:")
printList(head)
 
n = 3
 
head = deleteNodeAtGivenPos(head, n)
 
print("\nDoubly linked list after deletion:")
 
printList(head)
# Out:
# Doubly linked list before deletion:
# 1<-->3<-->4<-->
# Doubly linked list after deletion:
# 1<-->3<-->

# %%
# Ques 4: Write a function that takes a start and end number as input and prints the integers in that range while printing Sabudh for every number divisible by 2, Foundation for every number divisible by 3 and Sabudh Foundation for number divisible by both 3 and 2.

# Example:

# Input:

# 1

# 7

# Output:

# 1

# Sabudh

# Foundation

# Sabudh

# 5

# Sabudh Foundation

# 7

def main(start, end):
    for i in range(start, end + 1):
        if (i % 2 == 0) & (i % 3 == 0):
            print("Sabudh Foundation")
        elif (i % 2 == 0):
            print("Sabudh")
        elif (i % 3 == 0):
            print("Foundation")
        else: 
            print(i)
            
start = int(input("Enter Starting Number: "))
end = int(input("Ender Ending Number: "))

main(start, end)
# Out:
# Enter Starting Number: 1
# Ender Ending Number: 10
# 1
# Sabudh
# Foundation
# Sabudh
# 5
# Sabudh Foundation
# 7
# Sabudh
# Foundation
# Sabudh

# %%
# Ques 5: Write a Program that takes a list of numbers as input and returns the maximum number from the list.

# Example:

# Input:

# [1,3,5,2,45,32]

# Output:

# 45
list = []
  
num = int(input("Enter number of elements in list: "))
  
for i in range(1, num + 1):
    ele = int(input("Enter elements: "))
    list.append(ele)
      
print("Largest element: ", max(list))
# Out:
# Enter number of elements in list: 6
# Enter elements: 1
# Enter elements: 2
# Enter elements: 3
# Enter elements: 5
# Enter elements: 45
# Enter elements: 32
# Largest element:  45

# %%
# Name: Gautam Jain URN: 1905785 CRN: 1915312 Btech CSE C1
